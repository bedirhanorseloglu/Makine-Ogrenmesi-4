# %% [markdown]
# - Amaç iki sınıf arasındaki ayrımın optimum olmasını sağlayacak hiper-düzlemi bulmak.
#
# <br/>
#
# - Bu fotoğraftaki kesikli çizgiler destek(support) noktalarını belirtir.
#
# ![image.png](attachment:image.png)
#
#
# <br/>
#
#
# - Elimizdeki veriler sürekli olarak bu şekilde doğrusal olmayabilir. Bu sepekle direkt bir doğru olarak sınıflandırmayı sağlayamayabiliyoruz. Bunu gidermek için <span style="color:red">Boyut Artırma</span> dediğimiz yöntemleri kullanıyoruz. Yani 2 boyutlu olan bu görünümü 3 boyutlu hale getiriyoruz. Buna  <span style="color: red;">Kernel Hilesi (Kernel Trick)</span> adı veriliyor.
#
# - Modelin detaylarını incelediğimizde kernel attribute'unun olduğunu görüyoruz. Buradaki attribute değeri <span style="color: red;">"kernel = rbf" (Radial Bases Function)</span>. rbf değerinin olması demek <span style="color: red;">DOĞRUSAL OLMAYAN FORM </span> demek
#
# ![image-2.png](attachment:image-2.png)
